# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
data = pd.read_csv('results_get_popular.csv')

# %%
# plot the results
threads = data['threads']
throughtput = data['throughput']
plt.plot(threads, throughtput)
plt.xlabel('Number of Concurrent Users')
plt.ylabel('Throughput (requests/second)')
plt.title('Throughput vs Number of Concurrent Users')
plt.grid(True)
plt.xlim(0, max(threads) + 1)
plt.ylim(0, max(throughtput)+100)
# Out:
# (0.0, 6448.31)

# %%
# plot the results
threads = data['threads']
response_time = data['response_time']
plt.plot(threads, response_time)
plt.xlabel('Number of Concurrent Users')
plt.ylabel('Response Time (ms)')
plt.title('Response Time vs Number of Concurrent Users')
plt.grid(True)
plt.ylim(0, max(response_time))
plt.xlim(0, max(threads) +1)
# Out:
# (0.0, 11.0)

# %%
# plot the results
threads = data['threads']
cpu_usage = data['cpu_util']
plt.plot(threads, cpu_usage)    
plt.xlabel('Number of Concurrent Users')
plt.ylabel('CPU Utilization (%)')
plt.title('CPU Utilization vs Number of Concurrent Users')
plt.grid(True)
plt.ylim(0, 100)
plt.xlim(0, max(threads) + 1)
# Out:
# (0.0, 11.0)

# %%
# plot the results
threads = data['threads']
disk_util = data['disk_util']
plt.plot(threads, disk_util)
plt.xlabel('Number of Concurrent Users')
plt.ylabel('Disk Utilization (%)')
plt.title('Disk Utilization vs Number of Concurrent Users')
plt.grid(True)
plt.ylim(0, 20)
plt.xlim(0, max(threads) + 1)
# Out:
# (0.0, 11.0)

# %%
put_all_data = pd.read_csv('results_put_all.csv')

# %%
threads = put_all_data['threads']
put_all_throughtput = put_all_data['throughput']
plt.plot(threads, put_all_throughtput)
plt.xlabel('Number of Concurrent Users')
plt.ylabel('Throughput (requests/second)')
plt.title('PUT All Throughput vs Number of Concurrent Users')
plt.grid(True)
plt.xlim(0, max(threads) + 1)
plt.ylim(0, max(put_all_throughtput)+2)
# Out:
# (0.0, 231.824)

# %%
threads = put_all_data['threads']
put_all_response_time = put_all_data['response_time']
plt.plot(threads, put_all_response_time)
plt.xlabel('Number of Concurrent Users')
plt.ylabel('Response Time (ms)')
plt.title('PUT All Response Time vs Number of Concurrent Users')
plt.grid(True)
plt.ylim(0, max(put_all_response_time))
plt.xlim(0, max(threads) +1)
# Out:
# (0.0, 11.0)

# %%
threads = put_all_data['threads']
put_all_cpu_usage = put_all_data['cpu_util']
plt.plot(threads, put_all_cpu_usage)
plt.xlabel('Number of Concurrent Users')
plt.ylabel('CPU Utilization (%)')
plt.title('PUT All CPU Utilization vs Number of Concurrent Users')
plt.grid(True)
plt.ylim(0, 100)    
plt.xlim(0, max(threads) + 1)
# Out:
# (0.0, 11.0)

# %%
threads = put_all_data['threads']
put_all_disk_util = put_all_data['disk_util']
plt.plot(threads, put_all_disk_util)
plt.xlabel('Number of Concurrent Users')
plt.ylabel('Disk Utilization (%)')
plt.title('PUT All Disk Utilization vs Number of Concurrent Users')
plt.grid(True)
plt.ylim(0, 100)
plt.xlim(0, max(threads) + 1)
# Out:
# (0.0, 11.0)
